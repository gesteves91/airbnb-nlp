# %% [markdown]
# # Feature Engineering the Airbnb Data

# %%
# import libraries
import pandas as pd
import numpy as np

# %%
# avoid om
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# read the data
df = pd.read_csv("../data/combined-files.csv", error_bad_lines=False)
# Out:
# b'Skipping line 389268: expected 106 fields, saw 111\nSkipping line 389269: expected 106 fields, saw 111\nSkipping line 389270: expected 106 fields, saw 111\nSkipping line 389271: expected 106 fields, saw 111\nSkipping line 389272: expected 106 fields, saw 111\nSkipping line 389273: expected 106 fields, saw 111\nSkipping line 389274: expected 106 fields, saw 111\nSkipping line 389275: expected 106 fields, saw 111\nSkipping line 389276: expected 106 fields, saw 111\nSkipping line 389277: expected 106 fields, saw 111\nSkipping line 389278: expected 106 fields, saw 111\nSkipping line 389279: expected 106 fields, saw 111\nSkipping line 389280: expected 106 fields, saw 111\nSkipping line 389281: expected 106 fields, saw 111\nSkipping line 389282: expected 106 fields, saw 111\nSkipping line 389283: expected 106 fields, saw 111\nSkipping line 389284: expected 106 fields, saw 111\nSkipping line 389285: expected 106 fields, saw 111\nSkipping line 389286: expected 106 fields, saw 111\nSkipping line 389287: expected 106 fields, saw 111\nSkipping line 389288: expected 106 fields, saw 111\nSkipping line 389289: expected 106 fields, saw 111\nSkipping line 389290: expected 106 fields, saw 111\nSkipping line 389291: expected 106 fields, saw 111\nSkipping line 389292: expected 106 fields, saw 111\nSkipping line 389293: expected 106 fields, saw 111\nSkipping line 389294: expected 106 fields, saw 111\nSkipping line 389295: expected 106 fields, saw 111\nSkipping line 389296: expected 106 fields, saw 111\nSkipping line 389297: expected 106 fields, saw 111\nSkipping line 389298: expected 106 fields, saw 111\nSkipping line 389299: expected 106 fields, saw 111\nSkipping line 389300: expected 106 fields, saw 111\nSkipping line 389301: expected 106 fields, saw 111\nSkipping line 389302: expected 106 fields, saw 111\nSkipping line 389303: expected 106 fields, saw 111\nSkipping line 389304: expected 106 fields, saw 111\nSkipping line 389305: expected 106 fields, saw 111\nSkipping line 389306: expected 106 fields, saw 111\nSkipping line 389307: expected 106 fields, saw 111\nSkipping line 389308: expected 106 fields, saw 111\nSkipping line 389309: expected 106 fields, saw 111\nSkipping line 389310: expected 106 fields, saw 111\nSkipping line 389311: expected 106 fields, saw 111\nSkipping line 389312: expected 106 fields, saw 111\nSkipping line 389313: expected 106 fields, saw 111\nSkipping line 389314: expected 106 fields, saw 111\nSkipping line 389315: expected 106 fields, saw 111\nSkipping line 389316: expected 106 fields, saw 111\nSkipping line 389317: expected 106 fields, saw 111\nSkipping line 389318: expected 106 fields, saw 111\nSkipping line 389319: expected 106 fields, saw 111\nSkipping line 389320: expected 106 fields, saw 111\nSkipping line 389321: expected 106 fields, saw 111\nSkipping line 389322: expected 106 fields, saw 111\nSkipping line 389323: expected 106 fields, saw 111\nSkipping line 389324: expected 106 fields, saw 111\nSkipping line 389325: expected 106 fields, saw 111\nSkipping line 389326: expected 106 fields, saw 111\nSkipping line 389327: expected 106 fields, saw 111\nSkipping line 389328: expected 106 fields, saw 111\nSkipping line 389329: expected 106 fields, saw 111\nSkipping line 389330: expected 106 fields, saw 111\nSkipping line 389331: expected 106 fields, saw 111\nSkipping line 389332: expected 106 fields, saw 111\nSkipping line 389333: expected 106 fields, saw 111\nSkipping line 389334: expected 106 fields, saw 111\nSkipping line 389335: expected 106 fields, saw 111\nSkipping line 389336: expected 106 fields, saw 111\nSkipping line 389337: expected 106 fields, saw 111\nSkipping line 389338: expected 106 fields, saw 111\nSkipping line 389339: expected 106 fields, saw 111\nSkipping line 389340: expected 106 fields, saw 111\nSkipping line 389341: expected 106 fields, saw 111\nSkipping line 389342: expected 106 fields, saw 111\nSkipping line 389343: expected 106 fields, saw 111\nSkipping line 389344: expected 106 fields, saw ...

# %%
df.shape
# Out:
# (1235454, 106)

# %% [markdown]
# ### Delete columns

# %%
df = df.drop('id', 1)
df = df.drop('listing_url', 1)
df = df.drop('scrape_id', 1)
df = df.drop('last_scraped', 1)
df = df.drop('name', 1)
df = df.drop('summary', 1)
df = df.drop('space', 1)
df = df.drop('description', 1)
df = df.drop('neighborhood_overview', 1)
df = df.drop('notes', 1)
df = df.drop('transit', 1)
df = df.drop('access', 1)
df = df.drop('interaction', 1)
df = df.drop('house_rules', 1)
df = df.drop('thumbnail_url', 1)
df = df.drop('medium_url', 1)
df = df.drop('picture_url', 1)
df = df.drop('xl_picture_url', 1)
df = df.drop('host_id', 1)
df = df.drop('host_url', 1)
df = df.drop('host_name', 1)
df = df.drop('host_since', 1)
df = df.drop('host_location', 1)
df = df.drop('host_about', 1)
df = df.drop('host_thumbnail_url', 1)
df = df.drop('host_picture_url', 1)
df = df.drop('host_neighbourhood', 1)
df = df.drop('street', 1)
df = df.drop('neighbourhood', 1)
df = df.drop('neighbourhood_cleansed', 1)
df = df.drop('neighbourhood_group_cleansed', 1)
df = df.drop('city', 1)
df = df.drop('state', 1)
df = df.drop('zipcode', 1)
df = df.drop('market', 1)
df = df.drop('smart_location', 1)
df = df.drop('country_code', 1)
df = df.drop('country', 1)
df = df.drop('latitude', 1)
df = df.drop('longitude', 1)
df = df.drop('square_feet', 1)
df = df.drop('calendar_updated', 1)
df = df.drop('first_review', 1)
df = df.drop('last_review', 1)
df = df.drop('license', 1)
df = df.drop('jurisdiction_names', 1)
df = df.drop('experiences_offered', 1)
df = df.drop('host_acceptance_rate', 1)
df = df.drop('calendar_last_scraped', 1)
df = df.drop('monthly_price', 1)
df = df.drop('weekly_price', 1)

# %%
df['amenities'] = df['amenities'].astype(str)

# %%
df['host_verifications_count'] = df.apply(lambda row: row.host_verifications.count(',') + 1, axis=1)

# %%
df['amenities_count'] = df.apply(lambda row: row.amenities.count(',') + 1 if not type(row) is float else 0, axis=1)

# %%
df = df.drop('host_verifications', 1)
df = df.drop('amenities', 1)

# %%
df.head(3)
# Out:
#   host_response_time host_response_rate host_is_superhost host_listings_count  \
# 0     within an hour               100%                 t                   1
# 1     within an hour               100%                 f                   2
# 2     within an hour               100%                 f                   2
#
#   host_total_listings_count host_has_profile_pic host_identity_verified  \
# 0                         1                    t                      f
# 1                         2                    t                      f
# 2                         2                    t                      f
#
#   is_location_exact property_type        room_type accommodates bathrooms  \
# 0                 f     Apartment     Private room            2       1.5
# 1                 t     Townhouse     Private room            2         1
# 2                 f     Apartment  Entire home/apt            3         1
#
#   bedrooms beds  bed_type    price security_deposit cleaning_fee  \
# 0        1    2  Real Bed   $59.00          $200.00       $60.00
# 1        1    1  Real Bed   $80.00              NaN          NaN
# 2        1    1  Real Bed  $125.00          $300.00       $40.00
#
#   guests_included extra_people minimum_nights maximum_nights  \
# 0               1       $20.00              3             15
# 1               2        $0.00              1           1000
# 2               2       $10.00             14             60
#
#   minimum_minimum_nights maximum_minimum_nights minimum_maximum_nights  \
# 0                      3                      3                     15
# 1                      1                      4                   1000
# 2                     14                     14                     60
#
#   maximum_maximum_nights minimum_nights_avg_ntm maximum_nights_avg_ntm  \
# 0                     15                      3                     15
# 1                   1000                    3.4                   1000
# 2                     60                     14                     60
#
#   has_availability availability_30 availability_60 availability_90  \
# 0                t               8              18              43
# 1                t               0               8              34
# 2                t               4               6              16
#
#   availability_365 number_of_reviews number_of_reviews_ltm  \
# 0               89               267                    30
# 1              124               283                    67
# 2               75                 3                     2
#
#   review_scores_rating review_scores_accuracy review_scores_cleanliness  \
# 0                   98                     10                        10
# 1                   88                      9                        10
# 2                  100                     10                        10
#
#   review_scores_checkin review_scores_communication review_scores_location  \
# 0                    10                          10                     10
# 1                    10                          10                     10
# 2                    10                          10                     10
#
#   review_scores_value requires_license instant_bookable  \
# 0                  10                f                t
# 1                   9                f                f
# 2                  10                f                f
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f  strict_14_with_grace_period
# 1                        f  strict_14_with_grace_period
# 2                        f  strict_14_with_grace_period
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             f                                f
# 2                             f                                f
#
#   calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 0                              1                                           0
# 1                              2                                           0
# 2                              2                                           2
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            1
# 1                                            2
# 2                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month  \
# 0                                           0              2.12
# 1                                           0              2.46
# 2                                           0              0.16
#
#    host_verifications_count  amenities_count
# 0                         8               36
# 1                         8               19
# 2                         3               23

# %%
df.isna().sum()
# Out:
# host_response_time                              306705
# host_response_rate                              306630
# host_is_superhost                                  855
# host_listings_count                                855
# host_total_listings_count                          855
# host_has_profile_pic                               855
# host_identity_verified                            1720
# is_location_exact                                    0
# property_type                                        2
# room_type                                            3
# accommodates                                         2
# bathrooms                                         1206
# bedrooms                                           626
# beds                                              3226
# bed_type                                             0
# price                                              507
# security_deposit                                435723
# cleaning_fee                                    330113
# guests_included                                      0
# extra_people                                         0
# minimum_nights                                     388
# maximum_nights                                       0
# minimum_minimum_nights                               0
# maximum_minimum_nights                               0
# minimum_maximum_nights                               0
# maximum_maximum_nights                               0
# minimum_nights_avg_ntm                               0
# maximum_nights_avg_ntm                             189
# has_availability                                   197
# availability_30                                    199
# availability_60                                    200
# availability_90                                    199
# availability_365                                   199
# number_of_reviews                                  200
# number_of_reviews_ltm                                0
# review_scores_rating                            339233
# review_scores_accuracy                          339876
# review_scores_cleanliness                       339675
# review_scores_checkin                           340344
# review_scores_communication                     339907
# review_scores_location                          340379
# review_scores_value                             341323
# requires_license                                     0
# instant_bookable                                   866
# is_business_travel_ready                           866
# cancellation_policy                                891
# require_guest_profile_picture                      866
# require_guest_phone_verification                   866
# calculated_host_listings_count                     866
# calculated_host_listings_count_entire_homes        866
# calculated_host_listings_count_private_rooms       866
# calculated_host_listings_count_shared_rooms        866
# reviews_per_month                               320479
# host_verifications_count                             0
# amenities_count                                      0
# dtype: int64

# %% [markdown]
# ### One hot-encoding

# %%
df.shape
# Out:
# (1235454, 55)

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (521306, 55)

# %%
# import preprocessing from sklearn
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
# Out:
# /home/geanderson/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/_multiprocessing_helpers.py:38: UserWarning: [Errno 12] Cannot allocate memory.  joblib will operate in serial mode
#   warnings.warn('%s.  joblib will operate in serial mode' % (e,))

# %%
# encoding these columns that are 0/1
df['host_is_superhost'] = le.fit_transform(df.host_is_superhost.values)
df['host_has_profile_pic'] = le.fit_transform(df.host_has_profile_pic.values)
df['host_identity_verified'] = le.fit_transform(df.host_identity_verified.values)
df['is_location_exact'] = le.fit_transform(df.is_location_exact.values)
df['has_availability'] = le.fit_transform(df.has_availability.values)
df['requires_license'] = le.fit_transform(df.requires_license.values)
df['instant_bookable'] = le.fit_transform(df.instant_bookable.values)
df['is_business_travel_ready'] = le.fit_transform(df.is_business_travel_ready.values)
df['require_guest_profile_picture'] = le.fit_transform(df.require_guest_profile_picture.values)
df['require_guest_phone_verification'] = le.fit_transform(df.require_guest_phone_verification.values)

# %%
# encoding the language categorical feature
df = pd.get_dummies(df, columns = ['host_response_time', 'property_type', 'room_type', 'bed_type', 'cancellation_policy'])

# %%
df.head(3)
# Out:
#   host_response_rate  host_is_superhost host_listings_count  \
# 0               100%                  2                   1
# 2               100%                  0                   2
# 3               100%                  2                   1
#
#   host_total_listings_count  host_has_profile_pic  host_identity_verified  \
# 0                         1                     2                       0
# 2                         2                     2                       0
# 3                         1                     2                       2
#
#    is_location_exact accommodates bathrooms bedrooms beds    price  \
# 0                  0            2       1.5        1    2   $59.00
# 2                  0            3         1        1    1  $125.00
# 3                  2            2         1        1    1  $150.00
#
#   security_deposit cleaning_fee guests_included extra_people minimum_nights  \
# 0          $200.00       $60.00               1       $20.00              3
# 2          $300.00       $40.00               2       $10.00             14
# 3            $0.00        $0.00               1        $0.00              2
#
#   maximum_nights minimum_minimum_nights maximum_minimum_nights  \
# 0             15                      3                      3
# 2             60                     14                     14
# 3            730                      2                      2
#
#   minimum_maximum_nights maximum_maximum_nights minimum_nights_avg_ntm  \
# 0                     15                     15                      3
# 2                     60                     60                     14
# 3                    730                    730                      2
#
#   maximum_nights_avg_ntm  has_availability availability_30 availability_60  \
# 0                     15                 1               8              18
# 2                     60                 1               4               6
# 3                    730                 1               6              13
#
#   availability_90 availability_365 number_of_reviews number_of_reviews_ltm  \
# 0              43               89               267                    30
# 2              16               75                 3                     2
# 3              26               66               195                    41
#
#   review_scores_rating review_scores_accuracy review_scores_cleanliness  \
# 0                   98                     10                        10
# 2                  100                     10                        10
# 3                   99                     10                        10
#
#   review_scores_checkin review_scores_communication review_scores_location  \
# 0                    10                          10                     10
# 2                    10                          10                     10
# 3                    10                          10                     10
#
#   review_scores_value  requires_license  instant_bookable  \
# 0                  10                 0                 2
# 2                  10                 0                 0
# 3                  10                 0                 2
#
#    is_business_travel_ready  require_guest_profile_picture  \
# 0                         0                              0
# 2                         0                              0
# 3                         0                              0
#
#    require_guest_phone_verification calculated_host_listings_count  \
# 0                                 0                              1
# 2                                 0                              2
# 3                                 0                              1
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           0
# 2                                           2
# 3                                           0
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            1
# 2                                            0
# 3                                            1
#
#   calculated_host_listings_count_shared_rooms reviews_per_month  \
# 0                                           0              2.12
# 2                                           0              0.16
# 3                                           0              2.11
#
#    host_verifications_count  amenities_count  \
# 0                         8               36
# 2                         3               23
# 3                         4               22
#
#    host_response_time_a few days or more  \
# 0                                      0
# 2                                      0
# 3                                      0
#
#    host_response_time_host_response_time  host_response_time_within a day  \
# 0                                      0                                0
# 2                                      0                                0
# 3                                      0                                0
#
#    host_response_time_within a few hours  host_response_time_within an hour  \
# 0                                      0                                  1
# 2                                      0                                  1
# 3                                      0                                  1
#
#    property_type_Aparthotel  property_type_Apartment  property_type_Barn  \
# 0                         0                        1                   0
# 2                         0                        1                   0
# 3                         0                        0                   0
#
#    property_type_Bed and breakfast  property_type_Boat  \
# 0                                0                   0
# 2                                0                   0
# 3                                0                   0
#
#    property_type_Boutique hotel  property_type_Bungalow  property_type_Bus  \
# 0                             0                       0                  0
# 2                             0                       0                  0
# 3                             0                       0                  0
#
#    property_type_Cabin  property_type_Camper/RV  property_type_Campsite  \
# 0                    0                        0                       0
# 2                    0                        0                       0
# 3                    0                        0                       0
#
#    property_type_Casa particular (Cuba)  property_type_Castle  \
# 0                                     0                     0
# 2                                     0                     0
# 3                                     0                     0
#
#    property_type_Cave  property_type_Chalet  property_type_Condohotel  \
# 0                   0                     0                         0
# 2                   0                     0                         0
# 3                   0                     0                         0
#
#    property_type_Condominium  property_type_Cottage  \
# 0                          0                      0
# 2                          0                      0
# 3                          0                      0
#
#    property_type_Cycladic house  property_type_Cycladic house (Greece)  \
# 0                             0                                      0
# 2                             0                                      0
# 3                             0                                      0
#
#    property_type_Dammuso (Italy)  property_type_Dome house  \
# 0                              0                         0
# 2                              0                         0
# 3                              0                         0
#
#    property_type_Dorm  property_type_Earth house  property_type_Farm stay  \
# 0                   0                          0                        0
# 2                   0                          0                        0
# 3                   0                          0                        0
#
#    property_type_Guest suite  property_type_Guesthouse  \
# 0                          0                         0
# 2                          0                         0
# 3                          0                         0
#
#    property_type_Heritage hotel (India)  property_type_Hostel  \
# 0                                     0                     0
# 2                                     0                     0
# 3                                     0                     0
#
#    property_type_Hotel  property_type_House  property_type_Houseboat  \
# 0                    0                    0                        0
# 2                    0                    0                        0
# 3                    0                    0                        1
#
#    property_type_Hut  property_type_Igloo  property_type_In-law  \
# 0                  0                    0                     0
# 2                  0                    0                     0
# 3                  0                    0                     0
#
#    property_type_Island  property_type_Lighthouse  property_type_Loft  \
# 0                     0                         0                   0
# 2                     0                         0                   0
# 3                     0                         0                   0
#
#    property_type_Minsu (Taiwan)  property_type_Nature lodge  \
# 0                             0                           0
# 2                             0                           0
# 3                             0                           0
#
#    property_type_Other  property_type_Pension (South Korea)  \
# 0                    0                                    0
# 2                    0                                    0
# 3                    0                                    0
#
#    property_type_Plane  property_type_Resort  property_type_Ryokan (Japan)  \
# 0                    0                     0                             0
# 2                    0                     0                             0
# 3                    0                     0                             0
#
#    property_type_Serviced apartment  \
# 0                                 0
# 2                                 0
# 3                                 0
#
#    property_type_Shepherd's hut (U.K., France)  property_type_Tent  \
# 0                                            0                   0
# 2                                            0                   0
# 3                                            0                   0
#
#    property_type_Timeshare  property_type_Tiny house  property_type_Tipi  \
# 0                        0                         0                   0
# 2                        0                         0                   0
# 3                        0                         0                   0
#
#    property_type_Townhouse  property_type_Train  property_type_Treehouse  \
# 0                        0                    0                        0
# 2                        0                    0                        0
# 3                        0                    0                        0
#
#    property_type_Trullo (Italy)  property_type_Vacation home  \
# 0                             0                            0
# 2                             0                            0
# 3                             0                            0
#
#    property_type_Villa  property_type_Windmill  property_type_Yurt  \
# 0                    0                       0                   0
# 2                    0                       0                   0
# 3                    0                       0                   0
#
#    property_type_property_type  room_type_Entire home/apt  \
# 0                            0                          0
# 2                            0                          1
# 3                            0                          0
#
#    room_type_Hotel room  room_type_Private room  room_type_Shared room  \
# 0                     0                       1                      0
# 2                     0                       0                      0
# 3                     0                       1                      0
#
#    room_type_room_type  bed_type_Airbed  bed_type_Couch  bed_type_Futon  \
# 0                    0                0               0               0
# 2                    0                0               0               0
# 3                    0                0               0               0
#
#    bed_type_Pull-out Sofa  bed_type_Real Bed  bed_type_bed_type  \
# 0                       0                  1                  0
# 2                       0                  1                  0
# 3                       0                  1                  0
#
#    cancellation_policy_cancellation_policy  cancellation_policy_flexible  \
# 0                                        0                             0
# 2                                        0                             0
# 3                                        0                             0
#
#    cancellation_policy_flexible_new  cancellation_policy_moderate  \
# 0                                 0                             0
# 2                                 0                             0
# 3                                 0                             0
#
#    cancellation_policy_moderate_new  cancellation_policy_strict  \
# 0                                 0                           0
# 2                                 0                           0
# 3                                 0                           0
#
#    cancellation_policy_strict_14_with_grace_period  \
# 0                                                1
# 2                                                1
# 3                                                1
#
#    cancellation_policy_strict_new  cancellation_policy_super_strict_30  \
# 0                               0                                    0
# 2                               0                                    0
# 3                               0                                    0
#
#    cancellation_policy_super_strict_30_new  \
# 0                                        0
# 2                                        0
# 3                                        0
#
#    cancellation_policy_super_strict_60  \
# 0                                    0
# 2                                    0
# 3                                    0
#
#    cancellation_policy_super_strict_60_new
# 0                                        0
# 2                                        0
# 3                                        0

# %%
# convert to float 100%
df.drop(df[df['host_response_rate'] == 'host_response_rate'].index, inplace = True)
df.drop(df[df['price'] == 'price'].index, inplace = True)

# %%
df['host_response_rate'] = df['host_response_rate'].str.rstrip('%').astype('float') / 100.0

# %%
df['price']=(df['price'].replace( '[\$,)]','', regex=True )
                   .replace( '[(]','-',   regex=True ).astype(float))
df['security_deposit']=(df['security_deposit'].replace( '[\$,)]','', regex=True )
                   .replace( '[(]','-',   regex=True ).astype(float))
df['cleaning_fee']=(df['cleaning_fee'].replace( '[\$,)]','', regex=True )
                   .replace( '[(]','-',   regex=True ).astype(float))
df['extra_people']=(df['extra_people'].replace( '[\$,)]','', regex=True )
                   .replace( '[(]','-',   regex=True ).astype(float))

# %% [markdown]
# #### Send Y to the end

# %%
satisfaction = df.review_scores_rating.values
df = df.drop('review_scores_rating', 1)
df['satisfaction'] = satisfaction

# %%
# save the csv
df.to_csv('../data/airbnb_total.csv')

# %%
df.shape
# Out:
# (521221, 138)
