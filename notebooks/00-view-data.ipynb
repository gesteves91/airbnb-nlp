# %%
# import libraries
import pandas as pd

# %%
# avoid om
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# read the data
df = pd.read_csv("../data/listings.csv.gz")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-278f9812e81b> in <module>
#       1 # read the data
# ----> 2 df = pd.read_csv("../data/listings.csv.gz")
#
# ~/sources/airbnb-nlp/envair/lib/python3.8/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...

# %%
df.shape
# Out:
# (8500, 106)

# %%
df.head(5)
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   2384   https://www.airbnb.com/rooms/2384  20190715000710   2019-07-15
# 1   4505   https://www.airbnb.com/rooms/4505  20190715000710   2019-07-15
# 2   7126   https://www.airbnb.com/rooms/7126  20190715000710   2019-07-15
# 3   9811   https://www.airbnb.com/rooms/9811  20190715000710   2019-07-15
# 4  10610  https://www.airbnb.com/rooms/10610  20190715000710   2019-07-15
#
#                                                 name  \
# 0  Hyde Park - Walk to UChicago/16 min Train Down...
# 1         We're back. 365 Great Reviews.  1 bad one.
# 2                Tiny Studio Apartment 94 Walk Score
# 3                      Barbara's Hideaway - Old Town
# 4                   3 Comforts of Cooperative Living
#
#                                              summary  \
# 0  Be the sole guest in a quiet, vintage, 2nd flo...
# 1  We took the winter off, made things nicer arou...
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df['review_scores_rating'].hist(bins=100)
